# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
output = pd.read_csv('outputpop.csv')
clientID, clientSec = '0d2beefe0f0846eea477a529f194cad5', '5fdcae7eaa6e420d932ecb01a9506bd8'
ccm = SpotifyClientCredentials(client_id=clientID, client_secret=clientSec)
sp = spotipy.Spotify(client_credentials_manager=ccm)

# %%
try:
    for i in range(len(output)+1):
        iden = output['id'][i]
        output['popularity'][i] = sp.track(f'spotify:track:{iden}')['popularity']
except:
    print(i)
    output.to_csv('outputpop.csv', index = False)
# Out:
# C:\Users\charl\Nueva carpeta\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 1348734

# %%
output['popularity'].hist(bins = 100)

# %%
bool_series = pd.isnull(output['time_signature'])
output[bool_series]
# Out:
# Empty DataFrame
# Columns: [acousticness, artists, danceability, duration_ms, energy, explicit, id, instrumentalness, key, liveness, loudness, mode, name, popularity, release_date, speechiness, tempo, valence, year, album, album_id, artist_ids, track_number, disc_number, time_signature]
# Index: []
#
# [0 rows x 25 columns]

# %%
bool_series = pd.isnull(output['time_signature'])
output[bool_series]
for i, row in output[bool_series].iterrows():
    iden = row['id']
    output['time_signature'][i] = sp.audio_features(f'spotify:track:{iden}')[0]['time_signature']
# Out:
# C:\Users\charl\Nueva carpeta\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 49988
# 50000
# 50034
# 50087
# 50140
# 50171
# 50205
# 50226
# 50291
# 50330
# 50388
# 50398
# 50404
# 50407
# 50442
# 50443
# 50453
# 50468
# 50499
# 50505
# 50523
# 50524
# 50558
# 50600
# 50601
# 50630
# 50642
# 50673
# 50686
# 50731
# 50732
# 50764
# 50847
# 50864
# 50877
# 50878
# 50947
# 50959
# 50960
# 50972
# 51026
# 51028
# 51063
# 51090
# 51091
# 51109
# 51111
# 51141
# 51161
# 51171
# 51194
# 51205
# 51224
# 51237
# 51252
# 51266
# 51272
# 51276
# 51279
# 51311
# 51342
# 51376
# 51409
# 51464
# 51470
# 51474
# 51488
# 51536
# 51551
# 51556
# 51571
# 51591
# 51595
# 51598
# 51604
# 51641
# ...

# %%
output.to_csv('outputpop.csv', index = False)
