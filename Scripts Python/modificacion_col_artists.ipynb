# %%
import pandas as pd
df = pd.read_csv('outputpop.csv', sep=',', encoding = 'ISO-8859-1')
df.head()
# Out:
#    acousticness               artists  danceability  duration_ms  energy  \
# 0           0.0         ['.bipolar.']         0.000       182000   0.000
# 1           0.0  ['3D House Of Beef']         0.000        59587   0.000
# 2           0.0        ['69 Fingers']         0.000        13573   0.000
# 3           0.0        ['A Novelist']         0.120       311828   0.809
# 4           0.0          ['Abdicate']         0.181       190373   0.983
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  3yY2ExH2Awk253MneKmOr8             0.000    0     0.000  ...
# 1         0  2H2dUoOaeMKjlh1AbJThPZ             0.000    0     0.000  ...
# 2         0  2R2gcyHJfDa33d4nMZn8bB             0.000    0     0.000  ...
# 3         0  5Osd5s2OcXUpb9DJGfdmqw             0.959    8     0.101  ...
# 4         0  3SNeLGUzbssH8djsbsR5tG             0.889    2     0.314  ...
#
#    speechiness    tempo valence  year                     album  \
# ...

# %%
import re

# %%
c = 0
for valor in df['artists']:
    valor = re.split(r',',valor)
    valor = valor[0]
    valor = re.findall(r'\s*\w+\s*',valor)
    res = ''
    for v in valor:
        res += v
    valor = res
    df['artists'][c] = valor
    c += 1
    if c== 100 or c == 1000 or c == 100000 or c== 250000 or c == 500000 or c == 750000 or c== 1000000 or c == 1250000:
        print(c)
df.head()
# Out:
# C:\Users\losaa\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# 100
# 1000
# 100000
# 250000
# 500000
# 750000
# 1000000
# 1250000
#    acousticness           artists  danceability  duration_ms  energy  \
# 0           0.0           bipolar         0.000       182000   0.000
# 1           0.0  3D House Of Beef         0.000        59587   0.000
# 2           0.0        69 Fingers         0.000        13573   0.000
# 3           0.0        A Novelist         0.120       311828   0.809
# 4           0.0          Abdicate         0.181       190373   0.983
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  3yY2ExH2Awk253MneKmOr8             0.000    0     0.000  ...
# ...

# %%
df.to_csv('datospopart1.csv', sep = ',')
